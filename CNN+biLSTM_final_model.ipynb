# %% [markdown]
# <a href="https://colab.research.google.com/github/KianBaghai/emg2qwerty/blob/main/CNN%2BbiLSTM_final_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # After all our experiments, we found our best model, and now will train it for the final time, for 150 epochs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/emg2qwerty
# Out:
# /content/drive/MyDrive/emg2qwerty

# %%
# !rm /content/drive/MyDrive/emg2qwerty/.git/index.lock
# %cd /content/drive/MyDrive/emg2qwerty
# !git pull
# Out:
# rm: cannot remove '/content/drive/MyDrive/emg2qwerty/.git/index.lock': No such file or directory
# /content/drive/MyDrive/emg2qwerty
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 55 (delta 22), reused 18 (delta 16), pack-reused 24 (from 3)
# Unpacking objects: 100% (55/55), 78.14 KiB | 26.00 KiB/s, done.
# From https://github.com/KianBaghai/emg2qwerty
#    6db0728..d27e7c6  main              -> origin/main
#  * [new branch]      dataPreProcessing -> origin/dataPreProcessing
#  * [new branch]      dataTrainAMT      -> origin/dataTrainAMT
#  * [new branch]      transformers      -> origin/transformers
# Updating 6db0728..d27e7c6
# error: The following untracked working tree files would be overwritten by merge:
# 	CNN+LSTMandGRU_model_experiments.ipynb
# Please move or remove them before you merge.
# Aborting

# %%
# %pip install -r requirements.txt
# Out:
# ...
#   Using cached https://github.com/kpu/kenlm/archive/master.zip (553 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !python -m emg2qwerty.train \
  model=conv_rnn_ctc \
  module.rnn_layers=2 \
  module.dropout=0.2 \
  module.rnn_type=lstm \
  module.rnn_bidirectional=True \
  user=single_user \
  trainer.accelerator=gpu trainer.devices=1 \
  trainer.max_epochs=150
# Out:
# [2026-03-12 20:09:45,062][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...
